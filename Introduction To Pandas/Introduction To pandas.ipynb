# %%
import pandas as pd
#series for 1 dimensional
series = pd.Series(["Buildings" , "Houses" , "Villas"])
print(series)
# Out:
# 0    Buildings
# 1       Houses
# 2       Villas
# dtype: object

# %%
colours = pd.Series(["Red" , "Green" , "Blue"])
print(colours)
# Out:
# 0      Red
# 1    Green
# 2     Blue
# dtype: object

# %%
# Data frame is 2 dimensional
df = pd.DataFrame({ "Buildings ": series , "Colours": colours})
df
# Out:
#   Buildings  Colours
# 0  Buildings     Red
# 1     Houses   Green
# 2     Villas    Blue

# %% [markdown]
# # Exercise Question and Solution

# %%
foods = pd.Series(["Pizza" , "Burgers" , "Fries" , "Cookies"])
foods
# Out:
# 0      Pizza
# 1    Burgers
# 2      Fries
# 3    Cookies
# dtype: object

# %%
Dollar_price = pd.Series([20, 40 , 15 , 40])
Dollar_price
# Out:
# 0    20
# 1    40
# 2    15
# 3    40
# dtype: int64

# %%
Data_frame = pd.DataFrame({"Foods" : foods , "Dollar_price" : Dollar_price})
Data_frame
# Out:
#      Foods  Dollar_price
# 0    Pizza            20
# 1  Burgers            40
# 2    Fries            15
# 3  Cookies            40

# %%
#importing csv files
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# We Can Also import by Using Url as following
df = pd.read_csv("https://raw.githubusercontent.com/muhammad-umar-9/Machine-Learning/main/Introduction%20To%20Pandas/car-sales.csv")
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# exporting a data frame
car_sales.to_csv("exported-car-sales.csv" , index = False)

# %%
export_car_sales = pd.read_csv("exported-car-sales.csv" )
export_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # **Describe Data**

# %%
# Attributes have no brackets at end ()
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
# Functions are brackets at end ()
# Describe function only takes integer values
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_column = car_sales.columns
car_column
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
# Mean Value
car_sales.mean(numeric_only=True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
price_sum = car_sales["Price"].sum()
price_sum
# Out:
# '$4,000.00$5,000.00$7,000.00$22,000.00$3,500.00$4,500.00$7,500.00$7,000.00$6,250.00$9,700.00'

# %%
Doors_sum = car_sales["Doors"].sum()
Doors_sum
# Out:
# 40

# %%
values = pd.Series([2000 , 3000 , 4000])
values.sum()
# Out:
# 9000

# %%
sum_of_three = pd.Series(['Make' , 'Colour' , 'Doors'])
sum_of_three.sum()
# Out:
# 'MakeColourDoors'

# %%
# we can use list of coloumn names to select multiple columns
sum_of_two = car_sales[["Make" , "Colour"]].sum()
sum_of_two
# Out:
# Make      ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour        WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# dtype: object

# %% [markdown]
# # **Viewing and Selecting Data**

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(6)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales.tail(2)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %% [markdown]
# # Loc and iloc

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Loc gives us index value
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
flowers = pd.Series(["Rose" , "Jasmine" , "Lilly" , "Lotus"] , index = [3 , 5 ,3 , 9])
flowers
# Out:
# 3       Rose
# 5    Jasmine
# 3      Lilly
# 9      Lotus
# dtype: object

# %%
flowers.loc[3]
# Out:
# 3     Rose
# 3    Lilly
# dtype: object

# %%
# iloc gives us the position starts from zero
flowers.iloc[3]
# Out:
# 'Lotus'

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales.iloc[:2]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00

# %%
# as loc gives us index so it will gives us values until that index
car_sales.loc[:2]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales.Odometer (KM)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-cffc0afb7077> in <cell line: 1>()
# ----> 1 car_sales.Odometer (KM)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Odometer'

# %%
car_sales["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
car_sales = car_sales.rename(columns = {"Odometer (KM)" : "Odometer"})
car_sales
# Out:
#      Make Colour  Odometer  Doors       Price
# 0  Toyota  White    150043      4   $4,000.00
# 1   Honda    Red     87899      4   $5,000.00
# 2  Toyota   Blue     32549      3   $7,000.00
# 3     BMW  Black     11179      5  $22,000.00
# 4  Nissan  White    213095      4   $3,500.00
# 5  Toyota  Green     99213      4   $4,500.00
# 6   Honda   Blue     45698      4   $7,500.00
# 7   Honda   Blue     54738      4   $7,000.00
# 8  Toyota  White     60000      4   $6,250.00
# 9  Nissan  White     31600      4   $9,700.00

# %%
car_sales[car_sales["Colour"] == "Red"]
# Out:
#     Make Colour  Odometer  Doors      Price
# 1  Honda    Red     87899      4  $5,000.00

# %%
car_sales[car_sales["Odometer"] > 100000]
# Out:
#      Make Colour  Odometer  Doors      Price
# 0  Toyota  White    150043      4  $4,000.00
# 4  Nissan  White    213095      4  $3,500.00
